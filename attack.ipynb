# %%
# !python3 drive/attack/attack.py drive/attack/adult3.csv drive/attack/adult2.csv
# Out:
# /usr/local/lib/python3.6/dist-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# List of 35 compiled individual ops in this theano cache /root/.theano/compiledir_Linux-4.14.33+-x86_64-with-Ubuntu-17.10-artful-x86_64-3.6.3-64:
# sub directory/Op/a set of the different associated Theano type
# tmp8s9oiwb7 CrossentropySoftmax1HotWithBiasDx [TensorType(int32, vector), TensorType(float64, matrix), TensorType(float64, (True,))]
# tmpucprp7vu CrossentropySoftmaxArgmax1HotWithBias [TensorType(int32, vector), TensorType(float64, matrix), TensorType(float64, vector)]
# tmplydxffqu DimShuffle{x,x} [TensorType(float64, scalar), TensorType(int8, scalar)]
# tmp1_ht52yc DimShuffle{x} [TensorType(float64, scalar), TensorType(int8, scalar)]
# tmpndz6t33n DimShuffle{} [TensorType(float64, (True, True))]
# ...
